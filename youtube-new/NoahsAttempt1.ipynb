# %%
import pandas as pd

# %%
filename = "USvideos.csv"
json1 = pd.read_json("US_category_id.json")

# %%
df = pd.read_csv(filename)

# %%
json2 = (json1["items"])
#json2 = pd.DataFrame(json2)
json2
# Out:
# 0     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 5     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 6     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 7     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 8     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 9     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 10    {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 11    {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 12    {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 13    {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 14    {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 15    {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 16    {'kind': 'youtube#videoCategory', 'etag': '"m2...
# ...

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df2 = df.loc[df['likes'] == df["dislikes"]]
df2.sort_values("likes", ascending=False)
# Out:
#           video_id trending_date                                       title  \
# 14794  AmZJwThOfzE      18.28.01                    This fox being a derp...
# 12559  yUMalTN2OvM      18.17.01                            IoT kit robot #3
# 14196  Ow-plaMZHT8      18.25.01                old dodge stratus commercial
# 13965  Ow-plaMZHT8      18.24.01                old dodge stratus commercial
# 13714  Ow-plaMZHT8      18.23.01                old dodge stratus commercial
# ...            ...           ...                                         ...
# 12745  VoUEz9yQJ8w      18.18.01  RAPID EYE MOVEMENT⎪Official Teaser Trailer
# 12987  VoUEz9yQJ8w      18.19.01  RAPID EYE MOVEMENT⎪Official Teaser Trailer
# 14029  uGwcNjWrgaU      18.25.01                  Why Are Fat People a Joke?
# 14218  JWAvRIpuj1U      18.26.01   Vince McMahon's Major Sports Announcement
# 28955  9TUBf6l7FBg      18.16.04               Coachella 2018 LIVE Channel 1
#
# ...

# %%
df["Percent of likes to dislikes"] = df['likes']/(df['dislikes'] + df['likes'])

# %%
a = df.loc[(df["Percent of likes to dislikes"]>.45) & (df["Percent of likes to dislikes"]<.55)]
b=a.drop
# Out:
#           video_id trending_date  \
# 43     0tO_l_Ed5Rs      17.14.11
# 47     sbcbvuitiTc      17.14.11
# 133    X7flefV8tec      17.14.11
# 195    u7pV4vxD1bs      17.14.11
# 267    NZFhMSgbKKM      17.15.11
# ...            ...           ...
# 37190  s1RxsMYi2xw      18.27.05
# 37396  Ut7e-0X8lds      18.28.05
# 37400  s1RxsMYi2xw      18.28.05
# 37596  s1RxsMYi2xw      18.29.05
# 37806  s1RxsMYi2xw      18.30.05
#
#                                                    title  \
# 43     Matthew Santoro - FACTS (Official Music Video)...
# 47     Stephon Marbury and Jimmer Fredette fight in C...
# 133    President Bill Clinton On Dictators, Democracy...
# 195    World's first self-driving shuttle crashes on ...
# 267    Dennis Smith Jr. and LeBron James go back and ...
# ...                                                  ...
# 37190  A series loss to ‘Star-less Celtics’ will tarn...
# 37396  30-year-old evicted from parents' home speaks ...
# ...
