# %%
import pandas as pd

# %%
df = pd.read_csv("USVideos.csv")

newdf = df.sort_values(by = 'views', ascending = False)
newdf.drop_duplicates(subset = 'title', keep = 'first', inplace = True)
newdf


#va = df[df['category_id'] == 7]
#df[["channel_title", "title", "likes", "dislikes"]]
#va.count()
#df = df.sort_values(by = 'category_id', 24)


#df['category_id'].value_counts()
#df['likes'].describe()
#df.head(40)
# Out:
#           video_id trending_date  \
# 38547  VYOjWnS4cMY      18.02.06
# 6181   FlsCjmMhFmw      17.14.12
# 34708  ffxKSjUwKdU      18.14.05
# 34888  zEf423kYfqk      18.15.05
# 38273  7C2z4GqqS5E      18.01.06
# ...            ...           ...
# 160    qg0GdM60syI      17.14.11
# 12716  zeQaJGkFyqQ      18.18.01
# 14984  dQMZLXaa1L8      18.29.01
# 777    -JVITToppE0      17.17.11
# 14782  y6KYFcta4SE      18.28.01
#
#                                                    title        channel_title  \
# 38547  Childish Gambino - This Is America (Official V...  ChildishGambinoVEVO
# 6181   YouTube Rewind: The Shape of 2017 | #YouTubeRe...    YouTube Spotlight
# 34708               Ariana Grande - No Tears Left To Cry     ArianaGrandeVevo
# 34888  Becky G, Natti Natasha - Sin Pijama (Official ...           BeckyGVEVO
# 38273                BTS (방탄소년단) 'FAKE LOVE' Official MV              ibighit
# ...                                                  ...                  ...
# ...
